# %%
SAVED_MODEL_FILENAME = "saved_model"
FLOAT_TFL_MODEL_FILENAME = "float_model.tfl"
QUANTIZED_TFL_MODEL_FILENAME = "quantized_model.tfl"
TFL_CC_MODEL_FILENAME = "virtual_notepad_model_data.cc"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !unzip virtual_notepad_letter_data-1.zip
# !rm -rf sample_data
# !mkdir -p checkpoints
# Out:
# Archive:  virtual_notepad_letter_data-1.zip
#    creating: virtual_notepad_letter_data-1/virtual_notepad_letter_data-1/
#   inflating: virtual_notepad_letter_data-1/virtual_notepad_letter_data-1/wanddata_A.json
#   inflating: virtual_notepad_letter_data-1/virtual_notepad_letter_data-1/wanddata_B.json
#   inflating: virtual_notepad_letter_data-1/virtual_notepad_letter_data-1/wanddata_C.json
#   inflating: virtual_notepad_letter_data-1/virtual_notepad_letter_data-1/wanddata_D.json
#   inflating: virtual_notepad_letter_data-1/virtual_notepad_letter_data-1/wanddata_E.json
#   inflating: virtual_notepad_letter_data-1/virtual_notepad_letter_data-1/wanddata_F.json
#   inflating: virtual_notepad_letter_data-1/virtual_notepad_letter_data-1/wanddata_G.json
#   inflating: virtual_notepad_letter_data-1/virtual_notepad_letter_data-1/wanddata_H.json
#   inflating: virtual_notepad_letter_data-1/virtual_notepad_letter_data-1/wanddata_I.json
#   inflating: virtual_notepad_letter_data-1/virtual_notepad_letter_data-1/wanddata_J.json
#   inflating: virtual_notepad_letter_data-1/virtual_notepad_letter_data-1/wanddata_K.json
#   inflating: virtual_notepad_letter_data-1/virtual_notepad_letter_data-1/wanddata_L.json
#   inflating: virtual_notepad_letter_data-1/virtual_notepad_letter_data-1/wanddata_M.json
#   inflating: virtual_notepad_letter_data-1/virtual_notepad_letter_data-1/wanddata_N.json
#   inflating: virtual_notepad_letter_data-1/virtual_notepad_letter_data-1/wanddata_O.json
#   inflating: virtual_notepad_letter_data-1/virtual_notepad_letter_data-1/wanddata_P.json
#   inflating: virtual_notepad_letter_data-1/virtual_notepad_letter_data-1/wanddata_Q.json
#   inflating: virtual_notepad_letter_data-1/virtual_notepad_letter_data-1/wanddata_R.json
#   inflating: virtual_notepad_letter_data-1/virtual_notepad_letter_data-1/wanddata_S.json
#   inflating: virtual_notepad_letter_data-1/virtual_notepad_letter_data-1/wanddata_T.json
#   inflating: virtual_notepad_letter_data-1/virtual_notepad_letter_data-1/wanddata_U.json
#   inflating: virtual_notepad_letter_data-1/virtual_notepad_letter_data-1/wanddata_V.json
#   inflating: virtual_notepad_letter_data-1/virtual_notepad_letter_data-1/wanddata_W.json
#   inflating: virtual_notepad_letter_data-1/virtual_notepad_letter_data-1/wanddata_X.json
#   inflating: virtual_notepad_letter_data-1/virtual_notepad_letter_data-1/wanddata_Y.json
#   inflating: virtual_notepad_letter_data-1/virtual_notepad_letter_data-1/wanddata_Z.json

# %%
cd virtual_notepad_letter_data-1/
# Out:
# /content/drive/MyDrive/Colab Notebooks/virtual_notepad_letter_data-1

# %%
import glob
import json

strokes = []
for filename in glob.glob("virtual_notepad_letter_data-1/*.json"):
  with open(filename, "r") as file:
    file_contents = file.read()
  file_data = json.loads(file_contents)
  for stroke in file_data["strokes"]:
    stroke["filename"] = filename
    print(filename)
    strokes.append(stroke)
# Out:
# virtual_notepad_letter_data-1/wanddata_A.json
# virtual_notepad_letter_data-1/wanddata_A.json
# virtual_notepad_letter_data-1/wanddata_A.json
# virtual_notepad_letter_data-1/wanddata_A.json
# virtual_notepad_letter_data-1/wanddata_A.json
# virtual_notepad_letter_data-1/wanddata_A.json
# virtual_notepad_letter_data-1/wanddata_A.json
# virtual_notepad_letter_data-1/wanddata_A.json
# virtual_notepad_letter_data-1/wanddata_A.json
# virtual_notepad_letter_data-1/wanddata_A.json
# virtual_notepad_letter_data-1/wanddata_A.json
# virtual_notepad_letter_data-1/wanddata_A.json
# virtual_notepad_letter_data-1/wanddata_A.json
# virtual_notepad_letter_data-1/wanddata_A.json
# virtual_notepad_letter_data-1/wanddata_A.json
# virtual_notepad_letter_data-1/wanddata_A.json
# virtual_notepad_letter_data-1/wanddata_A.json
# virtual_notepad_letter_data-1/wanddata_A.json
# virtual_notepad_letter_data-1/wanddata_A.json
# virtual_notepad_letter_data-1/wanddata_A.json
# virtual_notepad_letter_data-1/wanddata_A.json
# virtual_notepad_letter_data-1/wanddata_A.json
# virtual_notepad_letter_data-1/wanddata_A.json
# virtual_notepad_letter_data-1/wanddata_B.json
# virtual_notepad_letter_data-1/wanddata_B.json
# virtual_notepad_letter_data-1/wanddata_B.json
# virtual_notepad_letter_data-1/wanddata_B.json
# virtual_notepad_letter_data-1/wanddata_B.json
# virtual_notepad_letter_data-1/wanddata_B.json
# virtual_notepad_letter_data-1/wanddata_B.json
# virtual_notepad_letter_data-1/wanddata_B.json
# virtual_notepad_letter_data-1/wanddata_B.json
# virtual_notepad_letter_data-1/wanddata_B.json
# virtual_notepad_letter_data-1/wanddata_B.json
# virtual_notepad_letter_data-1/wanddata_B.json
# virtual_notepad_letter_data-1/wanddata_B.json
# virtual_notepad_letter_data-1/wanddata_B.json
# virtual_notepad_letter_data-1/wanddata_B.json
# virtual_notepad_letter_data-1/wanddata_B.json
# virtual_notepad_letter_data-1/wanddata_B.json
# virtual_notepad_letter_data-1/wanddata_B.json
# virtual_notepad_letter_data-1/wanddata_B.json
# virtual_notepad_letter_data-1/wanddata_B.json
# virtual_notepad_letter_data-1/wanddata_C.json
# virtual_notepad_letter_data-1/wanddata_C.json
# virtual_notepad_letter_data-1/wanddata_C.json
# virtual_notepad_letter_data-1/wanddata_C.json
# virtual_notepad_letter_data-1/wanddata_C.json
# virtual_notepad_letter_data-1/wanddata_C.json
# virtual_notepad_letter_data-1/wanddata_C.json
# virtual_notepad_letter_data-1/wanddata_C.json
# virtual_notepad_letter_data-1/wanddata_C.json
# virtual_notepad_letter_data-1/wanddata_C.json
# virtual_notepad_letter_data-1/wanddata_C.json
# virtual_notepad_letter_data-1/wanddata_C.json
# virtual_notepad_letter_data-1/wanddata_C.json
# virtual_notepad_letter_data-1/wanddata_C.json
# virtual_notepad_letter_data-1/wanddata_C.json
# virtual_notepad_letter_data-1/wanddata_C.json
# virtual_notepad_letter_data-1/wanddata_C.json
# virtual_notepad_letter_data-1/wanddata_C.json
# virtual_notepad_letter_data-1/wanddata_C.json
# virtual_notepad_letter_data-1/wanddata_C.json
# virtual_notepad_letter_data-1/wanddata_C.json
# virtual_notepad_letter_data-1/wanddata_C.json
# virtual_notepad_letter_data-1/wanddata_C.json
# virtual_notepad_letter_data-1/wanddata_C.json
# virtual_notepad_letter_data-1/wanddata_C.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_D.json
# virtual_notepad_letter_data-1/wanddata_E.json
# virtual_notepad_letter_data-1/wanddata_E.json
# virtual_notepad_letter_data-1/wanddata_E.json
# virtual_notepad_letter_data-1/wanddata_E.json
# virtual_notepad_letter_data-1/wanddata_E.json
# virtual_notepad_letter_data-1/wanddata_E.json
# virtual_notepad_letter_data-1/wanddata_E.json
# virtual_notepad_letter_data-1/wanddata_E.json
# virtual_notepad_letter_data-1/wanddata_E.json
# virtual_notepad_letter_data-1/wanddata_E.json
# virtual_notepad_letter_data-1/wanddata_E.json
# virtual_notepad_letter_data-1/wanddata_E.json
# virtual_notepad_letter_data-1/wanddata_E.json
# virtual_notepad_letter_data-1/wanddata_E.json
# virtual_notepad_letter_data-1/wanddata_E.json
# virtual_notepad_letter_data-1/wanddata_E.json
# virtual_notepad_letter_data-1/wanddata_E.json
# virtual_notepad_letter_data-1/wanddata_E.json
# virtual_notepad_letter_data-1/wanddata_E.json
# virtual_notepad_letter_data-1/wanddata_E.json
# virtual_notepad_letter_data-1/wanddata_E.json
# virtual_notepad_letter_data-1/wanddata_E.json
# virtual_notepad_letter_data-1/wanddata_E.json
# virtual_notepad_letter_data-1/wanddata_E.json
# virtual_notepad_letter_data-1/wanddata_E.json
# virtual_notepad_letter_data-1/wanddata_E.json
# virtual_notepad_letter_data-1/wanddata_E.json
# virtual_notepad_letter_data-1/wanddata_F.json
# virtual_notepad_letter_data-1/wanddata_F.json
# virtual_notepad_letter_data-1/wanddata_F.json
# virtual_notepad_letter_data-1/wanddata_F.json
# virtual_notepad_letter_data-1/wanddata_F.json
# virtual_notepad_letter_data-1/wanddata_F.json
# virtual_notepad_letter_data-1/wanddata_F.json
# virtual_notepad_letter_data-1/wanddata_F.json
# virtual_notepad_letter_data-1/wanddata_F.json
# virtual_notepad_letter_data-1/wanddata_F.json
# virtual_notepad_letter_data-1/wanddata_F.json
# virtual_notepad_letter_data-1/wanddata_F.json
# virtual_notepad_letter_data-1/wanddata_F.json
# virtual_notepad_letter_data-1/wanddata_F.json
# virtual_notepad_letter_data-1/wanddata_F.json
# virtual_notepad_letter_data-1/wanddata_F.json
# virtual_notepad_letter_data-1/wanddata_F.json
# virtual_notepad_letter_data-1/wanddata_F.json
# virtual_notepad_letter_data-1/wanddata_F.json
# virtual_notepad_letter_data-1/wanddata_F.json
# virtual_notepad_letter_data-1/wanddata_F.json
# virtual_notepad_letter_data-1/wanddata_F.json
# virtual_notepad_letter_data-1/wanddata_F.json
# virtual_notepad_letter_data-1/wanddata_F.json
# virtual_notepad_letter_data-1/wanddata_F.json
# virtual_notepad_letter_data-1/wanddata_F.json
# virtual_notepad_letter_data-1/wanddata_F.json
# virtual_notepad_letter_data-1/wanddata_F.json
# virtual_notepad_letter_data-1/wanddata_F.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_G.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_H.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_I.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_J.json
# virtual_notepad_letter_data-1/wanddata_K.json
# virtual_notepad_letter_data-1/wanddata_K.json
# virtual_notepad_letter_data-1/wanddata_K.json
# virtual_notepad_letter_data-1/wanddata_K.json
# virtual_notepad_letter_data-1/wanddata_K.json
# virtual_notepad_letter_data-1/wanddata_K.json
# virtual_notepad_letter_data-1/wanddata_K.json
# virtual_notepad_letter_data-1/wanddata_K.json
# virtual_notepad_letter_data-1/wanddata_K.json
# virtual_notepad_letter_data-1/wanddata_K.json
# virtual_notepad_letter_data-1/wanddata_K.json
# virtual_notepad_letter_data-1/wanddata_K.json
# virtual_notepad_letter_data-1/wanddata_K.json
# virtual_notepad_letter_data-1/wanddata_K.json
# virtual_notepad_letter_data-1/wanddata_K.json
# virtual_notepad_letter_data-1/wanddata_K.json
# virtual_notepad_letter_data-1/wanddata_K.json
# virtual_notepad_letter_data-1/wanddata_K.json
# virtual_notepad_letter_data-1/wanddata_K.json
# virtual_notepad_letter_data-1/wanddata_K.json
# virtual_notepad_letter_data-1/wanddata_K.json
# virtual_notepad_letter_data-1/wanddata_K.json
# virtual_notepad_letter_data-1/wanddata_K.json
# virtual_notepad_letter_data-1/wanddata_K.json
# virtual_notepad_letter_data-1/wanddata_K.json
# virtual_notepad_letter_data-1/wanddata_K.json
# virtual_notepad_letter_data-1/wanddata_K.json
# virtual_notepad_letter_data-1/wanddata_K.json
# virtual_notepad_letter_data-1/wanddata_K.json
# virtual_notepad_letter_data-1/wanddata_K.json
# virtual_notepad_letter_data-1/wanddata_K.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_L.json
# virtual_notepad_letter_data-1/wanddata_M.json
# virtual_notepad_letter_data-1/wanddata_M.json
# virtual_notepad_letter_data-1/wanddata_M.json
# virtual_notepad_letter_data-1/wanddata_M.json
# virtual_notepad_letter_data-1/wanddata_M.json
# virtual_notepad_letter_data-1/wanddata_M.json
# virtual_notepad_letter_data-1/wanddata_M.json
# virtual_notepad_letter_data-1/wanddata_M.json
# virtual_notepad_letter_data-1/wanddata_M.json
# virtual_notepad_letter_data-1/wanddata_M.json
# virtual_notepad_letter_data-1/wanddata_M.json
# virtual_notepad_letter_data-1/wanddata_M.json
# virtual_notepad_letter_data-1/wanddata_M.json
# virtual_notepad_letter_data-1/wanddata_M.json
# virtual_notepad_letter_data-1/wanddata_M.json
# virtual_notepad_letter_data-1/wanddata_M.json
# virtual_notepad_letter_data-1/wanddata_M.json
# virtual_notepad_letter_data-1/wanddata_M.json
# virtual_notepad_letter_data-1/wanddata_M.json
# virtual_notepad_letter_data-1/wanddata_M.json
# virtual_notepad_letter_data-1/wanddata_M.json
# virtual_notepad_letter_data-1/wanddata_M.json
# virtual_notepad_letter_data-1/wanddata_M.json
# virtual_notepad_letter_data-1/wanddata_M.json
# virtual_notepad_letter_data-1/wanddata_N.json
# virtual_notepad_letter_data-1/wanddata_N.json
# virtual_notepad_letter_data-1/wanddata_N.json
# virtual_notepad_letter_data-1/wanddata_N.json
# virtual_notepad_letter_data-1/wanddata_N.json
# virtual_notepad_letter_data-1/wanddata_N.json
# virtual_notepad_letter_data-1/wanddata_N.json
# virtual_notepad_letter_data-1/wanddata_N.json
# virtual_notepad_letter_data-1/wanddata_N.json
# virtual_notepad_letter_data-1/wanddata_N.json
# virtual_notepad_letter_data-1/wanddata_N.json
# virtual_notepad_letter_data-1/wanddata_N.json
# virtual_notepad_letter_data-1/wanddata_N.json
# virtual_notepad_letter_data-1/wanddata_N.json
# virtual_notepad_letter_data-1/wanddata_N.json
# virtual_notepad_letter_data-1/wanddata_N.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_O.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_P.json
# virtual_notepad_letter_data-1/wanddata_Q.json
# virtual_notepad_letter_data-1/wanddata_Q.json
# virtual_notepad_letter_data-1/wanddata_Q.json
# virtual_notepad_letter_data-1/wanddata_Q.json
# virtual_notepad_letter_data-1/wanddata_Q.json
# virtual_notepad_letter_data-1/wanddata_Q.json
# virtual_notepad_letter_data-1/wanddata_Q.json
# virtual_notepad_letter_data-1/wanddata_Q.json
# virtual_notepad_letter_data-1/wanddata_Q.json
# virtual_notepad_letter_data-1/wanddata_Q.json
# virtual_notepad_letter_data-1/wanddata_Q.json
# virtual_notepad_letter_data-1/wanddata_Q.json
# virtual_notepad_letter_data-1/wanddata_Q.json
# virtual_notepad_letter_data-1/wanddata_Q.json
# virtual_notepad_letter_data-1/wanddata_Q.json
# virtual_notepad_letter_data-1/wanddata_Q.json
# virtual_notepad_letter_data-1/wanddata_Q.json
# virtual_notepad_letter_data-1/wanddata_Q.json
# virtual_notepad_letter_data-1/wanddata_Q.json
# virtual_notepad_letter_data-1/wanddata_Q.json
# virtual_notepad_letter_data-1/wanddata_Q.json
# virtual_notepad_letter_data-1/wanddata_Q.json
# virtual_notepad_letter_data-1/wanddata_Q.json
# virtual_notepad_letter_data-1/wanddata_Q.json
# virtual_notepad_letter_data-1/wanddata_Q.json
# virtual_notepad_letter_data-1/wanddata_Q.json
# virtual_notepad_letter_data-1/wanddata_Q.json
# virtual_notepad_letter_data-1/wanddata_Q.json
# virtual_notepad_letter_data-1/wanddata_Q.json
# virtual_notepad_letter_data-1/wanddata_Q.json
# virtual_notepad_letter_data-1/wanddata_Q.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_R.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_S.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_T.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_U.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_V.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_W.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_X.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Y.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json
# virtual_notepad_letter_data-1/wanddata_Z.json

# %%
import matplotlib.pyplot as plt

def plot_stroke(stroke):

  x_array = []
  y_array = []
  for coords in stroke["strokePoints"]:
    x_array.append(coords["x"])
    y_array.append(coords["y"])

  fig = plt.figure(figsize=(12.8, 4.8))
  fig.suptitle(stroke["label"])

  ax = fig.add_subplot(131)
  ax.set_xlabel('x')
  ax.set_ylabel('y')
  ax.set_xlim(-0.4, 0.4)
  ax.set_ylim(-0.4, 0.4)
  ax.plot(x_array, y_array)
  plt.show()

# %%
plot_stroke(strokes[20])

# %%
import math
import numpy as np
import PIL

FIXED_POINT = 256

def mul_fp(a, b):
  return (a * b) / FIXED_POINT

def div_fp(a, b):
  if b == 0:
    b = 1
  return (a * FIXED_POINT) / b

def float_to_fp(a):
  return math.floor(a * FIXED_POINT)

def norm_to_coord_fp(a, range_fp, half_size_fp):
  a_fp = float_to_fp(a)
  norm_fp = div_fp(a_fp, range_fp)
  return mul_fp(norm_fp, half_size_fp) + half_size_fp

def round_fp_to_int(a):
  return math.floor((a + (FIXED_POINT / 2)) / FIXED_POINT)

def gate(a, min, max):
  if a < min:
    return min
  elif a > max:
    return max
  else:
    return a

def rasterize_stroke(stroke_points, x_range, y_range, width, height):
  num_channels = 3
  buffer_byte_count = height * width * num_channels
  buffer = bytearray(buffer_byte_count)

  width_fp = width * FIXED_POINT
  height_fp = height * FIXED_POINT
  half_width_fp = width_fp / 2
  half_height_fp = height_fp / 2
  x_range_fp = float_to_fp(x_range)
  y_range_fp = float_to_fp(y_range)

  t_inc_fp = FIXED_POINT / len(stroke_points)

  one_half_fp = (FIXED_POINT / 2)

  for point_index in range(len(stroke_points) - 1):
    start_point = stroke_points[point_index]
    end_point = stroke_points[point_index + 1]
    start_x_fp = norm_to_coord_fp(start_point["x"], x_range_fp, half_width_fp)
    start_y_fp = norm_to_coord_fp(-start_point["y"], y_range_fp, half_height_fp)
    end_x_fp = norm_to_coord_fp(end_point["x"], x_range_fp, half_width_fp)
    end_y_fp = norm_to_coord_fp(-end_point["y"], y_range_fp, half_height_fp)
    delta_x_fp = end_x_fp - start_x_fp
    delta_y_fp = end_y_fp - start_y_fp

    t_fp = point_index * t_inc_fp
    if t_fp < one_half_fp:
      local_t_fp = div_fp(t_fp, one_half_fp)
      one_minus_t_fp = FIXED_POINT - local_t_fp
      red = round_fp_to_int(one_minus_t_fp * 255)
      green = round_fp_to_int(local_t_fp * 255)
      blue = 0
    else:
      local_t_fp = div_fp(t_fp - one_half_fp, one_half_fp)
      one_minus_t_fp = FIXED_POINT - local_t_fp
      red = 0
      green = round_fp_to_int(one_minus_t_fp * 255)
      blue = round_fp_to_int(local_t_fp * 255)
    red = gate(red, 0, 255)
    green = gate(green, 0, 255)
    blue = gate(blue, 0, 255)

    if abs(delta_x_fp) > abs(delta_y_fp):
      line_length = abs(round_fp_to_int(delta_x_fp))
      if delta_x_fp > 0:
        x_inc_fp = 1 * FIXED_POINT
        y_inc_fp = div_fp(delta_y_fp, delta_x_fp)
      else:
        x_inc_fp = -1 * FIXED_POINT
        y_inc_fp = -div_fp(delta_y_fp, delta_x_fp)
    else:
      line_length = abs(round_fp_to_int(delta_y_fp))
      if delta_y_fp > 0:
        y_inc_fp = 1 * FIXED_POINT
        x_inc_fp = div_fp(delta_x_fp, delta_y_fp)
      else:
        y_inc_fp = -1 * FIXED_POINT
        x_inc_fp = -div_fp(delta_x_fp, delta_y_fp)
    for i in range(line_length + 1):
      x_fp = start_x_fp + (i * x_inc_fp)
      y_fp = start_y_fp + (i * y_inc_fp)
      x = round_fp_to_int(x_fp)
      y = round_fp_to_int(y_fp)
      if (x < 0) or (x >= width) or (y < 0) or (y >= height):
        continue
      buffer_index = (y * width * num_channels) + (x * num_channels)
      buffer[buffer_index + 0] = red
      buffer[buffer_index + 1] = green
      buffer[buffer_index + 2] = blue
  
  np_buffer = np.frombuffer(buffer, dtype=np.uint8).reshape(height, width, num_channels)

  return np_buffer

# %%
raster = rasterize_stroke(strokes[300]["strokePoints"], 0.5, 0.5, 32, 32)
PIL.Image.fromarray(raster).resize((512, 512), PIL.Image.NEAREST)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F57EF3C8C40>

# %%
from pathlib import Path
import shutil

X_RANGE = 0.6
Y_RANGE = 0.6

def ensure_empty_dir(dirname):
  dirpath = Path(dirname)
  if dirpath.exists() and dirpath.is_dir():
    shutil.rmtree(dirpath)
  dirpath.mkdir()

def augment_points(points, move_range, scale_range, rotate_range):
  move_x = np.random.uniform(low=-move_range, high=move_range)
  move_y = np.random.uniform(low=-move_range, high=move_range)
  scale = np.random.uniform(low=1.0-scale_range, high=1.0+scale_range)
  rotate = np.random.uniform(low=-rotate_range, high=rotate_range)

  x_axis_x = math.cos(rotate) * scale
  x_axis_y = math.sin(rotate) * scale

  y_axis_x = -math.sin(rotate) * scale
  y_axis_y = math.cos(rotate) * scale

  new_points = []
  for point in points:
    old_x = point["x"]
    old_y = point["y"]
    new_x = (x_axis_x * old_x) + (x_axis_y * old_y) + move_x
    new_y = (y_axis_x * old_x) + (y_axis_y * old_y) + move_y
    new_points.append({"x": new_x, "y": new_y})

  return new_points

def save_strokes_as_images(strokes, root_folder, width, height, augment_count):
  ensure_empty_dir(root_folder)
  labels = set()
  for stroke in strokes:
    labels.add(stroke["label"].lower())
  for label in labels:
    label_path = Path(root_folder, label)
    ensure_empty_dir(label_path)

  label_counts = {}
  for stroke in strokes:
    points = stroke["strokePoints"]
    label = stroke["label"].lower()
    if label == "":
      raise Exception("Missing label for %s:%d" % (stroke["filename"], stroke["index"]))
    if label not in label_counts:
      label_counts[label] = 0
    label_count = label_counts[label]
    label_counts[label] += 1
    raster = rasterize_stroke(points, X_RANGE, Y_RANGE, width, height)
    image = PIL.Image.fromarray(raster)
    image.save(Path(root_folder, label, str(label_count) + ".png"))
    for i in range(augment_count):
      augmented_points = augment_points(points, 0.1, 0.1, 0.3)
      raster = rasterize_stroke(augmented_points, X_RANGE, Y_RANGE, width, height)
      image = PIL.Image.fromarray(raster)
      image.save(Path(root_folder, label, str(label_count) + "_a" + str(i) + ".png"))

# %%
IMAGE_WIDTH = 32
IMAGE_HEIGHT = 32

shuffled_strokes = strokes
np.random.shuffle(shuffled_strokes)

test_percentage = 10
validation_percentage = 10
train_percentage = 100 - (test_percentage + validation_percentage)

test_count = math.floor((len(shuffled_strokes) * test_percentage) / 100)
validation_count = math.floor((len(shuffled_strokes) * validation_percentage) / 100)
test_strokes = shuffled_strokes[0:test_count]
validation_strokes = shuffled_strokes[test_count:(test_count + validation_count)]
train_strokes = shuffled_strokes[(test_count + validation_count):]

save_strokes_as_images(test_strokes, "test", IMAGE_WIDTH, IMAGE_HEIGHT, 10)
save_strokes_as_images(validation_strokes, "validation", IMAGE_WIDTH, IMAGE_HEIGHT, 0)
save_strokes_as_images(train_strokes, "train", IMAGE_WIDTH, IMAGE_HEIGHT, 10)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import image_dataset_from_directory

validation_ds = image_dataset_from_directory(
    directory='validation',
    labels='inferred',
    label_mode='categorical',
    batch_size=32,
    image_size=(IMAGE_WIDTH, IMAGE_HEIGHT)).prefetch(buffer_size=32)

train_ds = image_dataset_from_directory(
    directory='train',
    labels='inferred',
    label_mode='categorical',
    batch_size=32,
    image_size=(IMAGE_WIDTH, IMAGE_HEIGHT)).prefetch(buffer_size=32)
# Out:
# Found 91 files belonging to 26 classes.
# Found 8107 files belonging to 26 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.axis("off")

# %%
from keras import layers

def make_model(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)

    # Entry block
    x = layers.Rescaling(1.0 / 255)(inputs)
    x = layers.Conv2D(16, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Dropout(0.5)(x)

    x = layers.Conv2D(32, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Dropout(0.5)(x)

    x = layers.Conv2D(64, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Dropout(0.5)(x)

    x = layers.GlobalAveragePooling2D()(x)
    activation = "softmax"
    units = num_classes

    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(units, activation=activation)(x)
    return keras.Model(inputs, outputs)

# %%
model = make_model(input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 3), num_classes=26)
keras.utils.plot_model(model, show_shapes=True)

# %%
epochs = 90

callbacks = [
    keras.callbacks.ModelCheckpoint("checkpoints/save_at_{epoch}.h5"),
]
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    train_ds, epochs=epochs, callbacks=callbacks, validation_data=validation_ds,
)
# Out:
# Epoch 1/90
# 254/254 [==============================] - 18s 60ms/step - loss: 0.2678 - accuracy: 0.0442 - val_loss: 0.1628 - val_accuracy: 0.0879
# Epoch 2/90
# 254/254 [==============================] - 15s 60ms/step - loss: 0.1698 - accuracy: 0.0656 - val_loss: 0.1597 - val_accuracy: 0.0879
# Epoch 3/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.1648 - accuracy: 0.0815 - val_loss: 0.1491 - val_accuracy: 0.1319
# Epoch 4/90
# 254/254 [==============================] - 15s 60ms/step - loss: 0.1615 - accuracy: 0.0978 - val_loss: 0.1447 - val_accuracy: 0.1538
# Epoch 5/90
# 254/254 [==============================] - 15s 60ms/step - loss: 0.1578 - accuracy: 0.1137 - val_loss: 0.1395 - val_accuracy: 0.2418
# Epoch 6/90
# 254/254 [==============================] - 16s 60ms/step - loss: 0.1545 - accuracy: 0.1290 - val_loss: 0.1359 - val_accuracy: 0.3297
# Epoch 7/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.1505 - accuracy: 0.1576 - val_loss: 0.1302 - val_accuracy: 0.3846
# Epoch 8/90
# 254/254 [==============================] - 16s 61ms/step - loss: 0.1461 - accuracy: 0.1713 - val_loss: 0.1273 - val_accuracy: 0.3626
# Epoch 9/90
# 254/254 [==============================] - 17s 65ms/step - loss: 0.1419 - accuracy: 0.2061 - val_loss: 0.1244 - val_accuracy: 0.3956
# Epoch 10/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.1384 - accuracy: 0.2240 - val_loss: 0.1187 - val_accuracy: 0.5385
# Epoch 11/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.1353 - accuracy: 0.2530 - val_loss: 0.1197 - val_accuracy: 0.4505
# Epoch 12/90
# 254/254 [==============================] - 15s 60ms/step - loss: 0.1322 - accuracy: 0.2710 - val_loss: 0.1099 - val_accuracy: 0.6044
# Epoch 13/90
# 254/254 [==============================] - 16s 61ms/step - loss: 0.1290 - accuracy: 0.2906 - val_loss: 0.1103 - val_accuracy: 0.5165
# Epoch 14/90
# 254/254 [==============================] - 16s 61ms/step - loss: 0.1258 - accuracy: 0.3174 - val_loss: 0.1561 - val_accuracy: 0.0989
# Epoch 15/90
# 254/254 [==============================] - 16s 60ms/step - loss: 0.1239 - accuracy: 0.3407 - val_loss: 0.0966 - val_accuracy: 0.6923
# Epoch 16/90
# 254/254 [==============================] - 16s 60ms/step - loss: 0.1224 - accuracy: 0.3465 - val_loss: 0.0990 - val_accuracy: 0.6484
# Epoch 17/90
# 254/254 [==============================] - 16s 60ms/step - loss: 0.1199 - accuracy: 0.3701 - val_loss: 0.0934 - val_accuracy: 0.7143
# Epoch 18/90
# 254/254 [==============================] - 18s 69ms/step - loss: 0.1187 - accuracy: 0.3836 - val_loss: 0.0892 - val_accuracy: 0.7033
# Epoch 19/90
# 254/254 [==============================] - 16s 61ms/step - loss: 0.1164 - accuracy: 0.3899 - val_loss: 0.1507 - val_accuracy: 0.1099
# Epoch 20/90
# 254/254 [==============================] - 15s 57ms/step - loss: 0.1158 - accuracy: 0.3945 - val_loss: 0.0899 - val_accuracy: 0.7143
# Epoch 21/90
# 254/254 [==============================] - 18s 67ms/step - loss: 0.1147 - accuracy: 0.4110 - val_loss: 0.1505 - val_accuracy: 0.1538
# Epoch 22/90
# 254/254 [==============================] - 15s 57ms/step - loss: 0.1128 - accuracy: 0.4269 - val_loss: 0.1103 - val_accuracy: 0.3626
# Epoch 23/90
# 254/254 [==============================] - 16s 63ms/step - loss: 0.1125 - accuracy: 0.4204 - val_loss: 0.0802 - val_accuracy: 0.7033
# Epoch 24/90
# 254/254 [==============================] - 16s 62ms/step - loss: 0.1102 - accuracy: 0.4368 - val_loss: 0.0790 - val_accuracy: 0.7582
# Epoch 25/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.1101 - accuracy: 0.4412 - val_loss: 0.0834 - val_accuracy: 0.7692
# Epoch 26/90
# 254/254 [==============================] - 16s 63ms/step - loss: 0.1096 - accuracy: 0.4402 - val_loss: 0.0854 - val_accuracy: 0.7033
# Epoch 27/90
# 254/254 [==============================] - 17s 65ms/step - loss: 0.1087 - accuracy: 0.4439 - val_loss: 0.0836 - val_accuracy: 0.7473
# Epoch 28/90
# 254/254 [==============================] - 19s 73ms/step - loss: 0.1078 - accuracy: 0.4527 - val_loss: 0.0732 - val_accuracy: 0.7692
# Epoch 29/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.1061 - accuracy: 0.4642 - val_loss: 0.0786 - val_accuracy: 0.8352
# Epoch 30/90
# 254/254 [==============================] - 15s 58ms/step - loss: 0.1059 - accuracy: 0.4721 - val_loss: 0.1473 - val_accuracy: 0.2527
# Epoch 31/90
# 254/254 [==============================] - 15s 57ms/step - loss: 0.1053 - accuracy: 0.4730 - val_loss: 0.0710 - val_accuracy: 0.9011
# Epoch 32/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.1052 - accuracy: 0.4749 - val_loss: 0.0717 - val_accuracy: 0.8462
# Epoch 33/90
# 254/254 [==============================] - 15s 58ms/step - loss: 0.1041 - accuracy: 0.4864 - val_loss: 0.0674 - val_accuracy: 0.8462
# Epoch 34/90
# 254/254 [==============================] - 15s 58ms/step - loss: 0.1032 - accuracy: 0.4904 - val_loss: 0.0687 - val_accuracy: 0.8791
# Epoch 35/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.1023 - accuracy: 0.4925 - val_loss: 0.0715 - val_accuracy: 0.9011
# Epoch 36/90
# 254/254 [==============================] - 15s 58ms/step - loss: 0.1015 - accuracy: 0.5050 - val_loss: 0.0854 - val_accuracy: 0.7143
# Epoch 37/90
# 254/254 [==============================] - 16s 62ms/step - loss: 0.1019 - accuracy: 0.4980 - val_loss: 0.0667 - val_accuracy: 0.9231
# Epoch 38/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.1013 - accuracy: 0.4990 - val_loss: 0.0698 - val_accuracy: 0.8901
# Epoch 39/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.1014 - accuracy: 0.4999 - val_loss: 0.0761 - val_accuracy: 0.7692
# Epoch 40/90
# 254/254 [==============================] - 15s 58ms/step - loss: 0.1000 - accuracy: 0.5144 - val_loss: 0.0648 - val_accuracy: 0.9231
# Epoch 41/90
# 254/254 [==============================] - 15s 58ms/step - loss: 0.0993 - accuracy: 0.5170 - val_loss: 0.0625 - val_accuracy: 0.9231
# Epoch 42/90
# 254/254 [==============================] - 15s 58ms/step - loss: 0.0995 - accuracy: 0.5200 - val_loss: 0.0623 - val_accuracy: 0.9231
# Epoch 43/90
# 254/254 [==============================] - 15s 57ms/step - loss: 0.0994 - accuracy: 0.5073 - val_loss: 0.0611 - val_accuracy: 0.8791
# Epoch 44/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.0981 - accuracy: 0.5288 - val_loss: 0.0631 - val_accuracy: 0.9341
# Epoch 45/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.0989 - accuracy: 0.5289 - val_loss: 0.0845 - val_accuracy: 0.6813
# Epoch 46/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.0976 - accuracy: 0.5292 - val_loss: 0.1041 - val_accuracy: 0.4615
# Epoch 47/90
# 254/254 [==============================] - 17s 66ms/step - loss: 0.0976 - accuracy: 0.5233 - val_loss: 0.0686 - val_accuracy: 0.9121
# Epoch 48/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.0974 - accuracy: 0.5309 - val_loss: 0.0803 - val_accuracy: 0.5824
# Epoch 49/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.0968 - accuracy: 0.5406 - val_loss: 0.0602 - val_accuracy: 0.9011
# Epoch 50/90
# 254/254 [==============================] - 16s 60ms/step - loss: 0.0966 - accuracy: 0.5323 - val_loss: 0.0585 - val_accuracy: 0.9341
# Epoch 51/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.0963 - accuracy: 0.5353 - val_loss: 0.0591 - val_accuracy: 0.8901
# Epoch 52/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.0963 - accuracy: 0.5382 - val_loss: 0.0658 - val_accuracy: 0.8901
# Epoch 53/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.0961 - accuracy: 0.5398 - val_loss: 0.0580 - val_accuracy: 0.9451
# Epoch 54/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.0956 - accuracy: 0.5473 - val_loss: 0.0568 - val_accuracy: 0.9341
# Epoch 55/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.0954 - accuracy: 0.5515 - val_loss: 0.0589 - val_accuracy: 0.9011
# Epoch 56/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.0951 - accuracy: 0.5457 - val_loss: 0.0606 - val_accuracy: 0.9341
# Epoch 57/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.0949 - accuracy: 0.5559 - val_loss: 0.0670 - val_accuracy: 0.8681
# Epoch 58/90
# 254/254 [==============================] - 18s 70ms/step - loss: 0.0950 - accuracy: 0.5522 - val_loss: 0.0550 - val_accuracy: 0.9231
# Epoch 59/90
# 254/254 [==============================] - 15s 60ms/step - loss: 0.0946 - accuracy: 0.5510 - val_loss: 0.0697 - val_accuracy: 0.8571
# Epoch 60/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.0941 - accuracy: 0.5606 - val_loss: 0.0598 - val_accuracy: 0.9121
# Epoch 61/90
# 254/254 [==============================] - 15s 60ms/step - loss: 0.0942 - accuracy: 0.5530 - val_loss: 0.0654 - val_accuracy: 0.8791
# Epoch 62/90
# 254/254 [==============================] - 15s 60ms/step - loss: 0.0935 - accuracy: 0.5609 - val_loss: 0.0539 - val_accuracy: 0.9231
# Epoch 63/90
# 254/254 [==============================] - 15s 60ms/step - loss: 0.0932 - accuracy: 0.5598 - val_loss: 0.0526 - val_accuracy: 0.9011
# Epoch 64/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.0932 - accuracy: 0.5630 - val_loss: 0.0631 - val_accuracy: 0.8681
# Epoch 65/90
# 254/254 [==============================] - 15s 58ms/step - loss: 0.0927 - accuracy: 0.5605 - val_loss: 0.0532 - val_accuracy: 0.9341
# Epoch 66/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.0924 - accuracy: 0.5694 - val_loss: 0.0550 - val_accuracy: 0.8901
# Epoch 67/90
# 254/254 [==============================] - 15s 60ms/step - loss: 0.0921 - accuracy: 0.5664 - val_loss: 0.0705 - val_accuracy: 0.8352
# Epoch 68/90
# 254/254 [==============================] - 18s 69ms/step - loss: 0.0918 - accuracy: 0.5725 - val_loss: 0.0554 - val_accuracy: 0.9011
# Epoch 69/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.0920 - accuracy: 0.5665 - val_loss: 0.0715 - val_accuracy: 0.7802
# Epoch 70/90
# 254/254 [==============================] - 16s 62ms/step - loss: 0.0927 - accuracy: 0.5658 - val_loss: 0.0526 - val_accuracy: 0.9231
# Epoch 71/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.0914 - accuracy: 0.5760 - val_loss: 0.0550 - val_accuracy: 0.9011
# Epoch 72/90
# 254/254 [==============================] - 16s 60ms/step - loss: 0.0919 - accuracy: 0.5719 - val_loss: 0.0500 - val_accuracy: 0.9011
# Epoch 73/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.0919 - accuracy: 0.5712 - val_loss: 0.0626 - val_accuracy: 0.9011
# Epoch 74/90
# 254/254 [==============================] - 15s 58ms/step - loss: 0.0904 - accuracy: 0.5869 - val_loss: 0.0648 - val_accuracy: 0.8681
# Epoch 75/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.0907 - accuracy: 0.5779 - val_loss: 0.0511 - val_accuracy: 0.9231
# Epoch 76/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.0917 - accuracy: 0.5775 - val_loss: 0.0513 - val_accuracy: 0.9341
# Epoch 77/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.0911 - accuracy: 0.5751 - val_loss: 0.0494 - val_accuracy: 0.9121
# Epoch 78/90
# 254/254 [==============================] - 18s 68ms/step - loss: 0.0911 - accuracy: 0.5743 - val_loss: 0.0548 - val_accuracy: 0.9341
# Epoch 79/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.0907 - accuracy: 0.5832 - val_loss: 0.0675 - val_accuracy: 0.8132
# Epoch 80/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.0905 - accuracy: 0.5817 - val_loss: 0.0515 - val_accuracy: 0.9231
# Epoch 81/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.0907 - accuracy: 0.5884 - val_loss: 0.0559 - val_accuracy: 0.9121
# Epoch 82/90
# 254/254 [==============================] - 15s 58ms/step - loss: 0.0897 - accuracy: 0.5857 - val_loss: 0.0510 - val_accuracy: 0.9231
# Epoch 83/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.0907 - accuracy: 0.5754 - val_loss: 0.0480 - val_accuracy: 0.9121
# Epoch 84/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.0899 - accuracy: 0.5925 - val_loss: 0.0523 - val_accuracy: 0.9231
# Epoch 85/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.0911 - accuracy: 0.5760 - val_loss: 0.0517 - val_accuracy: 0.9451
# Epoch 86/90
# 254/254 [==============================] - 15s 60ms/step - loss: 0.0898 - accuracy: 0.5859 - val_loss: 0.0516 - val_accuracy: 0.8901
# Epoch 87/90
# 254/254 [==============================] - 15s 59ms/step - loss: 0.0890 - accuracy: 0.5921 - val_loss: 0.0487 - val_accuracy: 0.9231
# Epoch 88/90
# 254/254 [==============================] - 17s 67ms/step - loss: 0.0886 - accuracy: 0.5941 - val_loss: 0.0502 - val_accuracy: 0.9341
# Epoch 89/90
# 254/254 [==============================] - 15s 60ms/step - loss: 0.0896 - accuracy: 0.5831 - val_loss: 0.0490 - val_accuracy: 0.9451
# Epoch 90/90
# 254/254 [==============================] - 15s 60ms/step - loss: 0.0889 - accuracy: 0.5818 - val_loss: 0.0568 - val_accuracy: 0.8791

# %%
print(model.evaluate(train_ds))
# Out:
# 254/254 [==============================] - 13s 50ms/step - loss: 0.0621 - accuracy: 0.8426
# [0.06213385984301567, 0.8426051735877991]

# %%
print(model.evaluate(validation_ds))
# Out:
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0568 - accuracy: 0.8791
# [0.05682911351323128, 0.8791208863258362]

# %%
import string

def predict_image(model, filename):
  img = keras.preprocessing.image.load_img(filename, target_size=(IMAGE_WIDTH, IMAGE_HEIGHT))
  img_array = keras.preprocessing.image.img_to_array(img)
  img_array = tf.expand_dims(img_array, 0)  # Create batch axis
  predictions = model.predict(img_array).flatten()
  predicted_label_index = np.argmax(predictions)
  predicted_score = predictions[predicted_label_index]
  letter = string.ascii_lowercase[predicted_label_index]
  return (letter, predicted_score)
  
index, score = predict_image(model, "test/c/1.png")

print(index, score)
# Out:
# 1/1 [==============================] - 1s 924ms/step
# c 0.47918314

# %%
from IPython.display import Image, display

SCORE_THRESHOLD = 0.75

correct_count = 0
wrong_count = 0
discarded_count = 0
for label_dir in glob.glob("test/*"):
  label = label_dir.split("/")[-1]  # extract the letter from the directory name
  # label = int(label_dir.replace("test/", ""))
  for filename in glob.glob(label_dir + "/*.png"):
    index, score = predict_image(model, filename)
    if score < SCORE_THRESHOLD:
      discarded_count += 1
      continue
    if index == label:
      correct_count += 1
    else:
      wrong_count += 1
      print("%s expected, %s found with score %f" % (label, index, score))
      display(Image(filename=filename))

correct_percentage = (correct_count / (correct_count + wrong_count)) * 100
print("%.1f%% correct (N=%d, %d unknown)" % (correct_percentage, (correct_count + wrong_count), discarded_count))
# Out:
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# a expected, g found with score 0.878740
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 99.6% correct (N=241, 760 unknown)

# %%
model.save(SAVED_MODEL_FILENAME)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _update_step_xla while saving (showing 4 of 4). These functions will not be directly callable after loading.

# %%
#!curl -L https://storage.googleapis.com/download.tensorflow.org/models/tflite/micro/virtual_notepad_saved_model_2021_01_02.tgz -o saved_model.tgz
#!tar -xzf saved_model.tgz

# %%
converter = tf.lite.TFLiteConverter.from_saved_model(SAVED_MODEL_FILENAME)
model_no_quant_tflite = converter.convert()

# Save the model to disk
open(FLOAT_TFL_MODEL_FILENAME, "wb").write(model_no_quant_tflite)

def representative_dataset():
  for filename in glob.glob("test/*/*.png"):
    img = keras.preprocessing.image.load_img(filename, target_size=(IMAGE_WIDTH, IMAGE_HEIGHT))
    img_array = keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create batch axis      for images, labels in train_ds.take(1):
    yield([img_array])
# Set the optimization flag.
converter.optimizations = [tf.lite.Optimize.DEFAULT]
# Enforce integer only quantization
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8
# Provide a representative dataset to ensure we quantize correctly.
converter.representative_dataset = representative_dataset
model_tflite = converter.convert()

# Save the model to disk
open(QUANTIZED_TFL_MODEL_FILENAME, "wb").write(model_tflite)
# Out:
# 32392

# %%
def predict_tflite(tflite_model, filename):
  img = keras.preprocessing.image.load_img(filename, target_size=(IMAGE_WIDTH, IMAGE_HEIGHT))
  img_array = keras.preprocessing.image.img_to_array(img)
  img_array = tf.expand_dims(img_array, 0)

  # Initialize the TFLite interpreter
  interpreter = tf.lite.Interpreter(model_content=tflite_model)
  interpreter.allocate_tensors()

  input_details = interpreter.get_input_details()[0]
  output_details = interpreter.get_output_details()[0]

  # If required, quantize the input layer (from float to integer)
  input_scale, input_zero_point = input_details["quantization"]
  if (input_scale, input_zero_point) != (0.0, 0):
    img_array = np.multiply(img_array, 1.0 / input_scale) + input_zero_point
    img_array = img_array.astype(input_details["dtype"])
  
  # Invoke the interpreter
  interpreter.set_tensor(input_details["index"], img_array)
  interpreter.invoke()
  pred = interpreter.get_tensor(output_details["index"])[0]
  
  # If required, dequantized the output layer (from integer to float)
  output_scale, output_zero_point = output_details["quantization"]
  if (output_scale, output_zero_point) != (0.0, 0):
    pred = pred.astype(np.float32)
    pred = np.multiply((pred - output_zero_point), output_scale)
  
  predicted_label_index = np.argmax(pred)
  predicted_score = pred[predicted_label_index]
  letter = string.ascii_lowercase[predicted_label_index]

  return (letter, predicted_score)

# %%
predict_tflite(model_no_quant_tflite, "test/a/2.png")
# Out:
# ('g', 0.51990825)

# %%
predict_tflite(model_tflite, "test/a/2.png")
# Out:
# ('g', 0.5859375)

# %%
from IPython.display import Image, display

correct_count = 0
wrong_count = 0
discarded_count = 0
for label_dir in glob.glob("test/*"):
  label = label_dir.split("/")[-1]  # extract the letter from the directory name
  # label = int(label_dir.replace("test/", ""))
  for filename in glob.glob(label_dir + "/*.png"):
    index, score = predict_tflite(model_tflite, filename)
    if score < 0.75:
      discarded_count += 1
      continue
    if index == label:
      correct_count += 1
    else:
      wrong_count += 1
      print("%s expected, %s found with score %f" % (label, index, score))
      display(Image(filename=filename))

correct_percentage = (correct_count / (correct_count + wrong_count)) * 100

print("%.1f%% correct (N=%d, %d unknown)" % (correct_percentage, (correct_count + wrong_count), discarded_count))
# Out:
# a expected, g found with score 0.894531
# 99.6% correct (N=231, 770 unknown)

# %%
import os
import pandas as pd

def get_dir_size(dir):
  size = 0
  for f in os.scandir(dir):
    if f.is_file():
      size += f.stat().st_size
    elif f.is_dir():
      size += get_dir_size(f.path)
  return size

# Calculate size
size_tf = get_dir_size(SAVED_MODEL_FILENAME)
size_no_quant_tflite = os.path.getsize(FLOAT_TFL_MODEL_FILENAME)
size_tflite = os.path.getsize(QUANTIZED_TFL_MODEL_FILENAME)

# Compare size
pd.DataFrame.from_records(
    [["TensorFlow", f"{size_tf} bytes", ""],
     ["TensorFlow Lite", f"{size_no_quant_tflite} bytes ", f"(reduced by {size_tf - size_no_quant_tflite} bytes)"],
     ["TensorFlow Lite Quantized", f"{size_tflite} bytes", f"(reduced by {size_no_quant_tflite - size_tflite} bytes)"]],
     columns = ["Model", "Size", ""], index="Model")
# Out:
#                                     Size
# Model
# TensorFlow                  702510 bytes
# TensorFlow Lite            104672 bytes   (reduced by 597838 bytes)
# TensorFlow Lite Quantized    32392 bytes   (reduced by 72280 bytes)

# %%
# Install xxd if it is not available
# !apt-get update && apt-get -qq install xxd
# Convert to a C source file, i.e, a TensorFlow Lite for Microcontrollers model
# !xxd -i {QUANTIZED_TFL_MODEL_FILENAME} > {TFL_CC_MODEL_FILENAME}
# Update variable names
REPLACE_TEXT = QUANTIZED_TFL_MODEL_FILENAME.replace('/', '_').replace('.', '_')
# !sed -i 's/'{REPLACE_TEXT}'/g_virtual_notepad_model_data/g' {TFL_CC_MODEL_FILENAME}
# Out:
# Get:1 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Hit:3 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Get:5 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Hit:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease
# Get:8 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ Packages [77.6 kB]
# Hit:9 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Hit:10 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Hit:11 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Hit:12 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal InRelease
# Get:13 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1,334 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3,150 kB]
# Fetched 4,901 kB in 2s (2,776 kB/s)
# Reading package lists... Done

# %%
# Print the C source file
# !tail {TFL_CC_MODEL_FILENAME}
# Out:
#   0x2c, 0x00, 0x00, 0x00, 0x18, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0xd0, 0xff, 0xff, 0xff, 0x19, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x19, 0xe0, 0xff, 0xff, 0xff, 0x09, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x09, 0xf0, 0xff, 0xff, 0xff,
#   0x28, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x28,
#   0x0c, 0x00, 0x10, 0x00, 0x0f, 0x00, 0x00, 0x00, 0x08, 0x00, 0x04, 0x00,
#   0x0c, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x03
# };
# unsigned int g_virtual_notepad_model_data_len = 32392;
